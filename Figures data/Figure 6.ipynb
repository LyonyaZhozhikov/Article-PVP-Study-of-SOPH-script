# %% [markdown]
# # PAE proximity

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['RAB18']
factors = ['x > 90', '70 < x ≤ 90', '50 < x ≤ 70', 'x ≤ 50']
values = np.array([[0, 9, 15, 0]])

fig, ax = plt.subplots()

colors = ['blue', 'cyan', 'yellow', 'orange']
fig.set_size_inches(8, 2)

total = np.sum(values)  # Total number of values

for i, cat in enumerate(categories):
    left = 0
    for j, fac in enumerate(factors):
        percentage = values[i][j] / total * 100  # Convert to percentage
        ax.barh(cat, percentage, color=colors[j], edgecolor='black', left=left, label=fac)
        left += percentage

plt.xlabel('%', size=30)

# Customize ticks
plt.xticks(size=40)
plt.yticks(size=40)

# Remove borders
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['ZW10']
factors = ['x > 90', '70 < x ≤ 90', '50 < x ≤ 70', 'x ≤ 50']
values = np.array([[0, 148, 59, 11]])

fig, ax = plt.subplots()

colors = ['blue', 'cyan', 'yellow', 'orange']
fig.set_size_inches(8, 2)

total = np.sum(values)  # Total number of values

for i, cat in enumerate(categories):
    left = 0
    for j, fac in enumerate(factors):
        percentage = values[i][j] / total * 100  # Convert to percentage
        ax.barh(cat, percentage, color=colors[j], edgecolor='black', left=left, label=fac)
        left += percentage

plt.xlabel('%', size=30)

# Customize ticks
plt.xticks(size=40)
plt.yticks(size=40)

# Remove borders
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['UPF3B']
factors = ['x > 90', '70 < x ≤ 90', '50 < x ≤ 70', 'x ≤ 50']
values = np.array([[0, 13, 5, 0]])

fig, ax = plt.subplots()

colors = ['blue', 'cyan', 'yellow', 'orange']
fig.set_size_inches(8, 2)

total = np.sum(values)  # Total number of values

for i, cat in enumerate(categories):
    left = 0
    for j, fac in enumerate(factors):
        percentage = values[i][j] / total * 100  # Convert to percentage
        ax.barh(cat, percentage, color=colors[j], edgecolor='black', left=left, label=fac)
        left += percentage

plt.xlabel('%', size=30)

# Customize ticks
plt.xticks(size=40)
plt.yticks(size=40)

# Remove borders
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['USE1']
factors = ['x > 90', '70 < x ≤ 90', '50 < x ≤ 70', 'x ≤ 50']
values = np.array([[17, 35, 3, 0]])

fig, ax = plt.subplots()

colors = ['blue', 'cyan', 'yellow', 'orange']
fig.set_size_inches(8, 2)

total = np.sum(values)  # Total number of values

for i, cat in enumerate(categories):
    left = 0
    for j, fac in enumerate(factors):
        percentage = values[i][j] / total * 100  # Convert to percentage
        ax.barh(cat, percentage, color=colors[j], edgecolor='black', left=left, label=fac)
        left += percentage

plt.xlabel('%', size=30)

# Customize ticks
plt.xticks(size=40)
plt.yticks(size=40)

# Remove borders
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['PV']
factors = ['x > 90', '70 < x ≤ 90', '50 < x ≤ 70', 'x ≤ 50']
values = np.array([[16, 48, 6, 6]])

fig, ax = plt.subplots()

colors = ['blue', 'cyan', 'yellow', 'orange']
fig.set_size_inches(8, 2)

total = np.sum(values)  # Total number of values

for i, cat in enumerate(categories):
    left = 0
    for j, fac in enumerate(factors):
        percentage = values[i][j] / total * 100  # Convert to percentage
        ax.barh(cat, percentage, color=colors[j], edgecolor='black', left=left, label=fac)
        left += percentage

plt.xlabel('%', size=30)

# Customize ticks
plt.xticks(size=40)
plt.yticks(size=40)

# Remove borders
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['NBAS']
factors = ['x > 90', '70 < x ≤ 90', '50 < x ≤ 70', 'x ≤ 50']
values = np.array([[180, 1594, 334, 263]])

fig, ax = plt.subplots()

colors = ['blue', 'cyan', 'yellow', 'orange']
fig.set_size_inches(8, 2)

total = np.sum(values)  # Total number of values

for i, cat in enumerate(categories):
    left = 0
    for j, fac in enumerate(factors):
        percentage = values[i][j] / total * 100  # Convert to percentage
        ax.barh(cat, percentage, color=colors[j], edgecolor='black', left=left, label=fac)
        left += percentage

plt.xlabel('%', size=30)

# Customize ticks
plt.xticks(size=40)
plt.yticks(size=40)

# Remove borders
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['NBAS']
factors = ['x > 90', '70 < x ≤ 90', '50 < x ≤ 70', 'x ≤ 50']
values = np.array([[180, 1594, 334, 263]])

# Plot
fig, ax = plt.subplots()

# Colors for each factor
colors = ['blue', 'cyan', 'yellow', 'orange']
fig.set_size_inches(8, 2)
# Plot bars for each category
for i, cat in enumerate(categories):
    left = 0
    for j, fac in enumerate(factors):
        ax.barh(cat, values[i][j], color=colors[j], edgecolor='black', left=left, label=fac)
        left += values[i][j]

# Add title and labels
plt.title('')
plt.xlabel('AA',size=30)
plt.ylabel('')

# Customize ticks
plt.xticks(range(1,2371,749),size=40)
plt.yticks(size=40)

# Add legend
handles, labels = ax.get_legend_handles_labels()
plt.legend()# handles[::-1], labels[::-1], loc='upper right')

# Save the plot to a file (optional)
# plt.savefig('subdivided_barplot.png', bbox_inches='tight', dpi=300)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
categories = ['NBAS']
factors = ['pLDDT > 90', '70 < pLDDT ≤ 90', '50 < pLDDT ≤ 70', 'pLDDT ≤ 50']
values = [180, 1594, 334, 263]

# Colors for each factor
colors = ['blue', 'cyan', 'yellow', 'orange']

# Plot
plt.figure(figsize=(10, 1))  # Adjust the figure size as needed
for factor, color in zip(factors, colors):
    plt.bar(0, 0, color=color, label=factor)  # Adding invisible bars for legend
plt.legend(loc='center', ncol=4, fontsize=100)  # Customize legend

# Remove axis
plt.axis('off')

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

all_affected_aa = [256, 1, 517, 519, 777, 1549, 270, 271, 1053, 1055, 2335, 803, 804, 1578, 2346, 1073, 2104, 568, 64, 1097, 842, 845, 340, 343, 857, 348, 95, 1121, 103, 1129, 873, 877, 373, 1914, 892, 1918, 1921, 134, 903, 136, 137, 650, 396, 151, 409, 1178, 414, 671, 422, 937, 426, 1707, 940, 941, 1708, 1199, 1201, 2232, 187, 447, 448, 1474, 454, 202, 1743, 1495, 984, 731, 2269, 227, 747, 1517, 2287, 1521, 253, 254]

USE1_PAE = [599,600,601,602,603,683,684,685,686,687,688,689,690,691,692,693,694,695,696,697,698,699,700,701,702,712,713,714,715,716,717,718,719,720,721,722,723,724,725,726,727,728,729,730,731,732,733,734,735,736,737,738,739,740,741,742,743,744,745,746,747,748,749,750,751,752,753,754,755,756,757,758,759,760,761,762,763,764,765,766,767,768,769,770,771,772,773,774,775,776,777,778,779,788,789,791,792,796,816,817,818,819,820,821,822,823,824,825,826,827,828,829,830,831,832,833,834,838,839,840,841,842,843,844,845,846,847,848,849,850,851,852,853,854,855,856,857,858,859,860,861,862,863,864,865,866,867,868,869,870,871,872,873,874,875,876,877,878,879,880,881,882,883,884,885,886,887,888,889,890,891,892,893,894,895,896,897,898,899,900,901,902,903,904,905,906,907,908,909,910,911,912,913,914,915,916,917,918,919,920,921,922,923,924,925,926,927,928,929,930,931,932,933,934,935,936,937,938,939,940,941,942,943,953,954,957,958,966,967,968,969,970,971,972,975,984]
1178,1179,1180,1181,1182,1183,1192,1193,1194,1195,1196,1197,1198,1199,1200,1201,1202,1473,1474,1475,1476,1494,1495,1496,1516,1517,1521,1522,1530,1532,1541,1542,1543,1544,1545,1546,1547,1548,1549,1550,1551,1552,1553,1555,1556,1560,1561,1569,1570,1571,1572,1573,1574,1575,1576,1577,1578,1579,1580,1581,1582,1583,1584,1585,1605,1606,1608,1609,1626,1627,1628,1629,1630,1631,1632,1633,1635,1636,1637,1671,1672,1674,1675,1676,1677,1678,1683,1697,1698,1699,1700,1701,1702,1703,1704,1705,1706,1707,1708,1709,1710,1712,1713,1714,1716,1717,1718,1719,1720,1721,1722,1724,1726,1732,1735,1736,1737,1738,1739,1740,1741,1742,1743,1744,1745,1746,1747,1748,1749,1758,1759,1761,1762,1763,1855,1856,1873,1874,1875,1876,1877,1878,1879,1880,1884,1892,1893,1894,1895,1896,1897,1898,1899,1900,1901,1902,1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,1913,1914,1915,1916,1917,1918,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928,1951,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1989,1992,1993,2102,2103,2104,2105,2106,2107,2108,2109,2110,2111,2112,2230,2231,2232,2233,2234,2253,2264,2265,2266,2267,2268,2269,2270,2271,2272,2273,2274,2275,2277,2284,2285,2286,2287,2288,2289,2290,2291,2292,2294,2312,2328,2329,2330,2331,2332,2333,2334,2335,2336,2337,2338,2339,2340,2341,2342,2343,2345,2346,2347,2348,2349,2350,2351]

# Create the plot
plt.figure(figsize=(20, 1))

# Plot vertical lines for each affected amino acid
for aa in all_affected_aa:
    plt.vlines(aa, ymin=0, ymax=3, color='red', zorder=3)  # zorder ensures the red lines are plotted below other elements

# Define tick locations and labels for every 250 points on the x-axis
x_ticks = np.arange(0, 2371, 100)
x_tick_labels = [str(x) for x in x_ticks]

# USE1_PAE
for aa in USE1_PAE:
    plt.vlines(aa, ymin=1, ymax=2, color='#ffd700', zorder = 2)  # nowar
    
# UPF3B_PAE
for aa in UPF3B_PAE:
    plt.vlines(aa, ymin=2, ymax=3, color='#0099ff', zorder = 2)  # nowar
    
# RAB18_PAE
for aa in RAB18_PAE:
    plt.vlines(aa, ymin=2, ymax=3, color='purple', zorder = 2)  # zorder ensures the red lines are plotted below other elements
    
# ZW10_PAE
for aa in ZW10_PAE:
    plt.vlines(aa, ymin=1, ymax=2, color='green', zorder = 2)  # zorder ensures the red lines are plotted below other elements
    
for aa in PV_PAE:
    plt.vlines(aa, ymin=0, ymax=1, color='red')  # zorder ensures the red lines are plotted below other elements

# Set x and y axis limits
plt.xlim(0, 2371)
plt.ylim(0, 3)

# Set smaller axis values
plt.gca().tick_params(axis='x', which='both', labelsize=2)

# Set y axis ticks
plt.yticks([1, 2], ['', ''])

# Set custom tick locations and labels for x-axis
plt.xticks(x_ticks, x_tick_labels)

# Add labels and title
plt.xlabel('')

# Adjust the plot for publication quality
plt.gca().tick_params(axis='both', which='major', labelsize=14)
plt.gca().tick_params(axis='both', which='minor', labelsize=12)
plt.gca().spines['top'].set_linewidth(0.5)
plt.gca().spines['right'].set_linewidth(0.5)
plt.gca().spines['bottom'].set_linewidth(0.5)
plt.gca().spines['left'].set_linewidth(0.5)
plt.grid(False)

# Show the plot
plt.show()
